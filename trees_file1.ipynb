# %%
import random
class drzewo:
    
    def __init__(ddz, data):
        
        ddz.left = None
        ddz.right = None
        
        ddz.data = data
        
    """    
    def wprow(ddz, data):

        if ddz.data:
            if data < ddz.data:
                if ddz.left is None:
                    ddz.left = drzewo(data)
                else:
                    ddz.left.wprow(data)
            elif data > ddz.data:
                if ddz.right is None:
                    ddz.right = drzewo(data)
                else:
                    ddz.right.wprow(data)
        else:
            ddz.data = data    
    """
    
    def gen(ddz,N):
        
        if N == 0:
            ddz = None
        else:
            
            #x= input()
            x = input()
            ddz.data = x
            if ddz.left is None:
                ddz.left = drzewo(None)
            if ddz.right is None:
                ddz.right = drzewo(None)
            ddz.left.gen(int(N/2))
            ddz.right.gen(N-int(N/2)-1)
            
    #def insert    
        
    def PrintBin(ddz,h,spac = 10):
        
        
        if ddz.right:
            ddz.right.PrintBin(h+1,spac+1)
        wezel = ""
        for i in range(spac): wezel=wezel+"..."
        wezel=wezel+str(ddz.data)
        print(wezel)
        
        if ddz.left:
            ddz.left.PrintBin(h+1,spac+1)
        
    """    
    def PrintBin(ddz,spac = 10):
        
        
        if ddz.right:
            ddz.right.PrintBin(spac+1)
        wezel = ""
        for i in range(spac): wezel=wezel+"..."
        wezel=wezel+str(ddz.data)
        print(wezel)
        
        if ddz.left:
            ddz.left.PrintBin(spac+1)
    """      
        
        
    """
        if ddz.left:
            
            wezel = ""
            for i in range(spac): wezel=wezel+"..."
            wezel=wezel+str(ddz.data)
        
            print(wezel)
            
            ddz.left.PrintBin(spac-1)
        
        
        
        
        if ddz.right:
            
            wezel = ""
            for i in range(spac): wezel=wezel+"..."
            wezel=wezel+str(ddz.data)
        
            print(wezel)
            
            ddz.left.PrintBin(spac+1)
    """  
        
            
        
    
    
    
    
    def DrukujDrzewoBin(ddz,spac = 1):
       
        
    
        if ddz.left:
            ddz.left.DrukujDrzewoBin(spac-1)
        
        
        wezel = ""
        for i in range(spac): wezel=wezel+"..."
        wezel=wezel+str(ddz.data)
        print(wezel)
        #print(ddz.data)
        
        
        
        
        if ddz.right:
            ddz.right.DrukujDrzewoBin(spac+1)
    

    
    
    
    
    
    
    def szukanie(ddz, x):
        if ddz.left:
            ddz.left.szukanie(x)
        
        if ddz.data == x: print("Jest!",ddz.data)
            
        if ddz.right:
            ddz.right.szukanie(x)
    
"""    
root = drzewo(3)
root.(6)
root.wprow(2)
root.wprow(4)
root.wprow(3)
root.wprow(5)
root.wprow(1)

""" 
root = drzewo(1)
root.gen(6)

#root.DrukujDrzewoBin()
root.PrintBin(0,10)
root.szukanie(0)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# ....................................None
# .................................5
# .......................................None
# ....................................6
# .......................................None
# ..............................1
# .......................................None
# ....................................4
# .......................................None
# .................................2
# .......................................None
# ....................................3
# .......................................None

# %% [markdown]
# ##

# %%
root = drzewo(3)

# %%
root.DrukujDrzewoBin()
# Out:
# 3
